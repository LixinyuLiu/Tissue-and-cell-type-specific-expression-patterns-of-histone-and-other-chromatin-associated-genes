# %%
import pandas as pd

# %%
df = pd.read_excel('log(data+1).xlsx')

# %%
from matplotlib import pyplot as plt

# %%
df
# Out:
#                                                         Xbp1      Il7r  \
# NaN                                                 8.948367  4.643856
# 32 Unresolved                                       3.000000  3.700440
# 30 Excitatory 3                                     6.169925  1.000000
# 5 Astrocyte - Gfap                                  3.807355  2.584963
# 13 OPC                                              4.700440  4.700440
# 44 Excitatory 15                                    2.584963  3.700440
# 43 Excitatory 14                                    2.807355  4.954196
# 26 Inhibitory 9                                     0.000000  0.000000
# 21 Inhibitory 4                                     2.321928  2.000000
# 41 Excitatory 12                                    3.169925  4.087463
# 7 Astro - Svep1                                     1.000000  2.000000
# 19 Inhibitory 2                                     3.169925  0.000000
# ...

# %%
import numpy as np

# %%
df1 = np.matrix(df)

# %%
import math

# %%
df1 = np.log2(df1+ 1)

# %%
plt.imshow(df1)

# %%
import seaborn

# %%
seaborn.heatmap(df)

# %%
import seaborn as sns; sns.set(color_codes=True)
g = sns.clustermap(df, z_score=0)

# %%
df3 = pd.read_excel('singlecell_vs_candidates.xlsx')
df3 = pd.DataFrame(df3)
df3.set_index('Genes', inplace=True)
df3 = np.log2(df3)

# %%
sns.clustermap(df3)
